# %%
# !pip install pypdf
# !pip install python-docx
#####################################################
from pypdf import PdfReader
import os
from docx import Document
from docx.shared import Inches
from google.colab import drive
drive.mount('/content/drive')
################################################################
# Out:
# Collecting pypdf
#   Downloading pypdf-3.17.4-py3-none-any.whl (278 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: pypdf
# Successfully installed pypdf-3.17.4
# Collecting python-docx
#   Downloading python_docx-1.1.0-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.6/239.6 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-docx) (4.9.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from python-docx) (4.5.0)
# Installing collected packages: python-docx
# Successfully installed python-docx-1.1.0
# Mounted at /content/drive

# %%
pdf_path = "/content/drive/MyDrive/Colab Notebooks/AI Work/QAF Use Case/Research/Apple Cider Vinegar (Beverage)"
################################################################
listoffiles = os.listdir(pdf_path)
listoffiles
# Out:
# ['9 Unexpected Amazing Benefits of Apple Cider Vinegar (ACV) .pdf',
#  '和丝露Apple Vinegar & quotations.pdf',
#  'Delmonte Green Apple Fruit Drink New product Watch Video.pdf']

# %%
################################################################
for i in range(0,len(listoffiles)):
  reader = PdfReader(pdf_path+"/"+listoffiles[i])
  with open(os.path.join(pdf_path, listoffiles[i].replace(".pdf",".txt") ), 'a') as f:
    for page in reader.pages:
      f.write(page.extract_text() + "\n")
################################################################
